# %% [markdown]
# <a href="https://colab.research.google.com/github/danimaulana25/PVCK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# accesing my google drive
drive.mount('/content/drivet')
# Out:
# Mounted at /content/drivet

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Images/cat.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/cat.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4= cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/koala.jpg, img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))    #ubah - ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
# Red-Blue
plt.imshow(img_gray, cmap='RdBu')

# %%
# Green-Blue
plt.imshow(img_gray, cmap='GnBu')

# %%
plt.imshow(img3[20:115, 25:120])

# %%
plt.imshow(img_gray[5:30], cmap="Reds")

# %%
img7 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img7,pt1=(80,400),pt2=(200,150),color=(0,255,0),thickness=10)
cv.rectangle(img7,pt1=(600,600),pt2=(800,400),color=(0,255,0),thickness=10)
cv.rectangle(img7,pt1=(384,700),pt2=(510,150),color=(0,255,0),thickness=10)
cv.rectangle(img7,pt1=(100,500),pt2=(300,610),color=(0,255,0),thickness=10)
cv.rectangle(img7,pt1=(600,100),pt2=(200,510),color=(0,255,0),thickness=10)
plt.imshow(img7)

# %%
img8 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
fig = plt.figure(figsize=(5,5))    #ubah - ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img8)

# %%
img11 = cv.imread('/content/drive/MyDrive/PCVK/Images/cat.jpg')
plt.imshow(img11)


cv.rectangle(img11,pt1=(220,20),pt2=(650,400),color=(255,0,255),thickness=10)
plt.imshow(img11)


cv.circle(img11, center=(380,200),radius=200,color=(0,0,0),thickness=10)
plt.imshow(img11)

# %%
img_7 = cv.imread('/content/drive/MyDrive/PCVK/Images/cat.jpg')
plt.imshow(img_7)


img_rgb = cv.cvtColor(img_7,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)


cv.rectangle(img_rgb,pt1=(150,1000),pt2=(15,1200),color=(0,0,255),thickness=10)
plt.imshow(img_rgb)
